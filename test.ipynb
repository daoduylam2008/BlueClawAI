# %%
import llm
import utils
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
model = llm.LLM(0)

# %%
messages = {"messages": [
    {
        "role": "user",
        "content": "What is cybersecurity"
    }
]}

# %%
responses = (model.invoke(messages))

# %%
utils.ai_sort(responses)[0].content
# Out:
# 'Cybersecurity refers to the practices, technologies, and processes designed to protect digital information from unauthorized access, use, disclosure, disruption, modification, or destruction. This includes protecting against malware, viruses, spyware, adware, ransomware, and other types of cyber threats. Cybersecurity also involves ensuring the confidentiality, integrity, and availability (C'
