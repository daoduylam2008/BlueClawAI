# %%
from sentence_transformers import SentenceTransformer
import torch

# %%
embedding_model = SentenceTransformer("nomic-ai/nomic-embed-text-v1", trust_remote_code=True)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# <All keys matched successfully>

# %%
sentence = ["search_query: What is TSNE?", "search_query: Who is Laurens van der Maaten?"]

# %%
embedding = embedding_model.encode(sentence)
embedding.shape
# Out:
# (2, 768)

# %%
embedding
# Out:
# array([[ 1.09513635e-02,  5.74146844e-02, -1.10363662e-02, ...,
#          3.51702874e-05, -2.80921534e-02, -2.15999149e-02],
#        [-1.33671369e-02,  2.70913430e-02, -2.33673882e-02, ...,
#          2.87994649e-02, -1.06748017e-02,  2.88207233e-02]],
#       shape=(2, 768), dtype=float32)
