# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
import torch

# %%
datasets = load_dataset("Salesforce/xlam-function-calling-60k")
datasets.save_to_disk("datasets/")
# Out:
# xlam_function_calling_60k.json:   0%|          | 0.00/96.1M [00:00<?, ?B/s]
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/60000 [00:00<?, ? examples/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B-Instruct").to('mps')
# Out:
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]

# %%
# generator = pipeline("text-generation", model="meta-llama/Llama-3.2-1B-Instruct", device='mps')

# %%
input_text = "Create a file in my current directory named test.txt and write 'Hello, World!' in it."
inputs = tokenizer(input_text, return_tensors="pt").to('mps')
outputs = model.generate(**inputs, temperature=0.7)

for output in outputs:
    print(1)
    print(tokenizer.decode(output, skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 1
# Create a file in my current directory named test.txt and write 'Hello, World!' in it. Then, create a new directory named 'test' and add another file named test2.txt and add

# %%
# generator("How is the weather today?", max_length=50, num_return_sequences=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "How is the weather today? It's been raining all morning and I'm so glad I have a roof over my head.\nI love the rain. It's like the world is washing away all the dirt and grime and starting fresh. There's something so magical about it.\nI've been watching the raindrops on the windowpane, and it's like they're trying to tell me something. The way they're falling, the way they're covering the world outside, it's like they're painting a picture of a new world.\nI feel so lucky to be able to experience this kind of weather. It's like the world is reminding me of the beauty and wonder of life. And I'm grateful for that."}]
